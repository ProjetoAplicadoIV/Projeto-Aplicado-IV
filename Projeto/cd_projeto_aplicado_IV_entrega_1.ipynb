# %% [markdown]
#   <img src="https://raw.githubusercontent.com/scalabrinig/cdProjetoAplicadoIV/d093146488f56dfcf0ef286bcee8efe0e71b9c76/figuras/mackenzie_logo.jpg" width="25%" align="right"/>
#
# # **PROJETO APLICADO IV - Ciência de Dados EaD - 2024/02**
#
#
# # **Entrega 1**
#
# ---

# %% [markdown]
# # **Titulo do Projeto**:
#
# ---

# %%
#@title **Identificação do Grupo e Opção do Projeto**

#@markdown Integrantes do Grupo, nome completo em ordem alfabética (*informe: \<nome\>, \<matrícula\>*)
Aluno1 = 'IAGO FONSECA MARINHO PEREIRA ", 10407014' #@param {type:"string"}
Aluno2 = 'MURILO GUIMARAES, 10407400' #@param {type:"string"}
Aluno3 = 'VINICIUS VIEIRA DA CUNHA OLIVEIRA, 10407434' #@param {type:"string"}

# %% [markdown]
# # **Introdução**
# A poluição do ar é um problema sério que causa uma variedade de questões sociais e ambientais abrangentes. Quando se trata de saúde pública, a exposição prolongada a poluentes atmosféricos está diretamente ligada ao agravamento de várias doenças respiratórias e cardiovasculares, e pode levar à morte em casos mais graves. Além disso, o impacto no meio ambiente é significativo, pois a poluição do ar contamina corpos d'água, solo e ecossistemas naturais, prejudica a agricultura e acelera a deterioração das infraestruturas urbanas.
#
# Identificar os tipos de substâncias poluentes presentes na atmosfera e em que quantidade é um passo essencial para lidar com esse desafio ambiental urgente. A qualidade do ar em uma determinada área pode variar consideravelmente conforme sua proximidade de fontes geradoras de poluentes, das condições climáticas e da topografia local. A partir da detecção de uma má qualidade do ar, torna-se viável investigar suas origens e, portanto, eventualmente voltar-se para o planejamento e implementação de estratégias efetivas para controlar as emissões poluentes. É fundamental conscientizar e alertar as pessoas sobre os perigos para reduzir os impactos na saúde pública.
#
# Desde o ano de 2015, o Instituto de Energia e Meio Ambiente (IEMA) tem mantido a Plataforma da Qualidade do Ar, que busca promover a transparência em relação a esses dados ao disponibilizar informações e análises sobre o monitoramento da qualidade do ar no Brasil. Utilizando fontes acessíveis ao público, tanto relatórios estaduais anuais como fontes públicas, os dados possibilitam consultas através de índices, como o Índice de Qualidade do Ar (IQAr), bem como comparações com os padrões nacionais e diretrizes estabelecidas pela Organização Mundial da Saúde (OMS).
#
# Neste projeto em questão, foi utilizado um conjunto de dados que adere à ideia de supervisão, contendo informações minuciosas referentes às quantidades de substâncias poluentes na atmosfera em diferentes locais e momentos específicos do dia.
#
# A finalidade desta pesquisa é investigar e examinar tais dados, a fim de identificar padrões temporais e geográficos na presença de substâncias poluentes, levando em consideração elementos como condições climáticas e a proximidade de fontes emissoras. Por meio dessas análises, almejamos fornecer percepções que possam contribuir para o desenvolvimento e aprimoração de políticas ambientais, além de promover a conscientização acerca dos impactos da poluição do ar na saúde e no ambiente.

# %% [markdown]
# # **Motivações e justificativa**
#
# CA poluição do ar não é apenas uma preocupação ambiental; também representa um desafio global de saúde pública. A exposição contínua a altos níveis de poluentes atmosféricos como partículas em suspensão e gases nocivos está relacionada ao aumento de problemas respiratórios e cardiovasculares e tem impactado significativamente o número de hospitalizações e mortes prematuras. Diante dessa seriedade da situação atualmente vivida pela sociedade em geral e reconhecendo a importância desse tema para a qualidade de vida das pessoas afetadas por isso tudo é crucial contar com uma ação conjunta entre governos agências de pesquisa e organizações civis na busca por solucionar essa questão e promover um bem-estar mais saudável para todos os cidadãos. Os benefícios desta pesquisa são realmente significativos tanto para a saúde pública quanto para a preservação do meio ambiente. Ao analisar minuciosamente os dados sobre poluição do ar é possível identificar padrões e discrepâncias que podem orientar políticas públicas mais adequadas à realidade local. Além disso,também será possível utilizar os resultados como base para campanhas de conscientização que alertem a população sobre os perigos da exposição a níveis elevados de poluentes e incentivem práticas mais sustentáveis no cotidiano como o uso de meios de transporte menos poluentes e o apoio a estratégias de redução das emissões. As possibilidades de utilização dessa pesquisa são imensas! Os dados obtidos podem ser empregados por governos e organizações na formulação de políticas ambientais mais sólidas direcionadas às demandas locais específicas. Além disso,, empresas do setor industrial têm muito a ganhar com essas avaliações ao aplicá-las para aprimorar suas práticas de gestão ambiental e diminuir o impacto ambiental que causam. Finalmente os dados produzidos também são de grande interesse para impulsionar o progressº de tecnologias novas de monitoramento e regulamentação da poluiçãoa contribuir para avançoes na área científica e na tecnologia voltada para a sustentabilidade.

# %% [markdown]
# # **Objetivo**
#
# Este projeto tem como objetivo examinar os padrões de poluentes atmosféricos ao longo do tempo e em diferentes áreas geográficas utilizando informações fornecidas pela Plataforma de Qualidade do Ar do Instituto de Energia e Meio Ambiente (IEMA). A análise visa identificar locais e momentos com níveis mais elevados de poluentes ao correlacionar esses dados com variáveis como as condições meteorológicas e a proximidade de fontes de emissão. Dessa forma, pretende-se auxiliar no desenvolvimento de políticas públicas destinadas a diminuir a poluição e preservar a saúde da população. Entre os objetivos estabelecidos está a detecção das variações sazonais e geográficas para permitir a implementação de medidas mais específicas pelas autoridades competentes. Além disso o estudo ajudará a compreender como fatores externos impactam as emissões e propagação de substâncias poluentes, o que resultará em ideias para iniciativas educacionais que alertem as pessoas sobre os perigos à saúde. Um outro propósito consiste em auxiliar gestores públicos e privados na tomada de decisões ao fornecer ferramentas analíticas para monitorar a qualidade do ar em tempo real e antecipar situações críticas. Com isso em mente o projeto planeja ajudar no avanço de políticas ambientais mais efetivas e estratégias de redução de emissões para favorecer uma melhoria na qualidade do ar e no bem-estar da população.

# %% [markdown]
# # **Descrição da base de dados**
# O conjunto de dados utilizado neste trabalho possui um total de 10.980.515 linhas e 9 colunas, contendo informações detalhadas sobre a concentração de poluentes atmosféricos medidas em diversas estações de monitoramento. Os dados abrangem o período de 2015 a 2021 e estão organizados em formato CSV.
# As informações disponíveis são descritas pelas seguintes variáveis:
#
# ID: índice inteiro que identifica de forma única cada registro do dataset.
# Data: data exata em que foi realizada a medição da concentração do poluente.
# Hora: horário específico em que a medição foi efetuada.
# Estação: local onde foi feita a medição, correspondente à estação de monitoramento da qualidade do ar.
# Código: código numérico associado à estação em que a medição foi realizada, servindo para identificar de forma única cada estação.
# Poluente: tipo de poluente cuja concentração foi medida, como material particulado, ozônio, dióxido de nitrogênio, entre outros.
# Valor: valor medido da concentração do poluente, expresso na unidade de medida especificada.
# Unidade: unidade de concentração utilizada para a medição (por exemplo, microgramas por metro cúbico).
# Tipo: tipo de medição realizada, que pode ser classificada como automática ou manual, dependendo do método utilizado para a coleta dos dados.
# Os dados foram extraídos da Plataforma da Qualidade do Ar, mantida pelo Instituto de Energia e Meio Ambiente (IEMA), com o objetivo de fornecer transparência e embasar análises relacionadas à poluição atmosférica no Brasil. A plataforma disponibiliza informações coletadas por meio de relatórios anuais estaduais e fontes públicas abertas, conforme descrito no portal oficial do IEMA (https://energiaeambiente.org.br/qualidadedoar/#secao-14).
# Esse conjunto de dados permitirá a investigação de padrões temporais e geográficos da concentração de poluentes, além de possibilitar análises sobre a variação da qualidade do ar em diferentes locais e momentos ao longo do período de 2015 a 2021.

# %%
#@title **Avaliação**
Relevancia = 10 #@param {type:"slider", min:0, max:10, step:1}

Fonte_dos_dados = 10 #@param {type:"slider", min:0, max:10, step:1}

Solucao_proposta = 10 #@param {type:"slider", min:0, max:10, step:1}

Referencias = 10 #@param {type:"slider", min:0, max:10, step:1}

Apresentacao_geral = 10 #@param {type:"slider", min:0, max:10, step:1}

# %%
#@title **Nota Final**
nota = 0.25*Relevancia + 0.25*Fonte_dos_dados + 0.25*Solucao_proposta + 0.15*Referencias + 0.10*Apresentacao_geral

print(f'Nota da entrega {nota :.1f}')

import numpy as np
import pandas as pd

alunos = pd.DataFrame()

lista_nome = []

for i in range(1,4):
  exec("if Aluno" + str(i) + " !='None':  lista = Aluno" + str(i) + ".split(','); lista_nome.append(lista[0]);")

alunos['nome'] = lista_nome
alunos['nota'] = np.round(nota,1)
print()
display(alunos)
# Out:
# Nota da entrega 8.5
#       nome  nota
# 0  Aluno 1   8.5
# 1  Aluno 2   8.5
# 2  Aluno 3   8.5
